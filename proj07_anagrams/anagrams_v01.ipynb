# %% [markdown]
# Solving Anagrams.
#
# Created by: Tony Held
# Created on: 2021-03-15
#
# References & Acknowledgements:
# 1) Inspired by `Impractical Python Projects` Chapter 3

# %%
# **********************************************
#     Jupyter Interactive Mode Settings
# **********************************************
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# **********************************************
#     Allows autocomplete to work properly
# **********************************************
# %config Completer.use_jedi = False

# %%
from anagrams_v01 import *

# %% [markdown]
# ## Find anagrams for single words

# %%
file_name = 'dictionaries/2of4brif.txt'
words = WordList(file_name)
words.print_most_frequent(5)
words.find_anagrams('bear')
words.find_anagrams('qwertyuiop')
# Out:
# Dictionary with 60388 entries loaded.
# The first and last 5 entries are:
# ['aah', 'aardvark', 'aardvarks', 'abacus', 'abacuses']
# ['zucchini', 'zucchinis', 'zydeco', 'zygote', 'zygotes']
#
# The first and last 5 entries are:
# [('a', 'a', 'h'), ('a', 'a', 'a', 'd', 'k', 'r', 'r', 'v'), ('a', 'a', 'a', 'd', 'k', 'r', 'r', 's', 'v'), ('a', 'a', 'b', 'c', 's', 'u'), ('a', 'a', 'b', 'c', 'e', 's', 's', 'u')]
# [('c', 'c', 'h', 'i', 'i', 'n', 'u', 'z'), ('c', 'c', 'h', 'i', 'i', 'n', 's', 'u', 'z'), ('c', 'd', 'e', 'o', 'y', 'z'), ('e', 'g', 'o', 't', 'y', 'z'), ('e', 'g', 'o', 's', 't', 'y', 'z')]
#
# The first 5 entries are:
# ('a', 'a', 'h'): [0, 1081]
# ('a', 'a', 'a', 'd', 'k', 'r', 'r', 'v'): [1]
# ('a', 'a', 'a', 'd', 'k', 'r', 'r', 's', 'v'): [2]
# ('a', 'a', 'b', 'c', 's', 'u'): [3]
# ('a', 'a', 'b', 'c', 'e', 's', 's', 'u'): [4]
# ('a', 'a', 'b', 'e', 'l', 'n', 'o'): [5]
# The 5 most frequent entries are:
# [[37517, 37583, 37953, 42605, 42901, 50023, 50092], [2415, 2544, 16755, 18191, 46890, 47335], [7579, 7694, 11935, 42799, 43022, 55124], [16260, 37098, 37584, 42655, 50024, 50557], [29874, 30153, 37199, 37946, 39392, 47284]]
#
# The 5 most frequently occurring anagrams in the word list are:
# 7 anagrams were found for these words:
# 	pares
# 	parse
# 	pears
# 	rapes
# 	reaps
# 	spare
# 	spear
# 6 anagrams were found for these words:
# 	ares
# 	arse
# 	ears
# 	eras
# 	sear
# 	sera
# 6 anagrams were found for these words:
# 	caster
# 	caters
# 	crates
# 	reacts
# 	recast
# 	traces
# 6 anagrams were found for these words:
# 	drapes
# 	padres
# 	parsed
# 	rasped
# 	spared
# 	spread
# 6 anagrams were found for these words:
# 	lapse
# 	leaps
# 	pales
# 	peals
# 	pleas
# 	sepal
#
# Anagrams for the word: bear
# 	1) bare
# 	2) bear
# 	3) brae
#
# Anagrams for the word: qwertyuiop
# 	Word not found in dictionary.

# %% [markdown]
# ## Find words that can be formed from a search word

# %%
search_word = 'tacotime'
my_indices, my_words = words.find_contained(search_word)
print(f'\nWords that can be found in *{search_word}*:\n\n{my_words}')
# Out:
# Words that can be found in *tacotime*:
#
# ['ace', 'acme', 'act', 'aim', 'am', 'at', 'ate', 'atom', 'atomic', 'attic', 'cam', 'came', 'cameo', 'cat', 'ciao', 'cite', 'coat', 'coma', 'come', 'comet', 'cot', 'eat', 'emit', 'ice', 'iota', 'it', 'item', 'ma', 'mac', 'mace', 'mat', 'mate', 'matt', 'matte', 'me', 'meat', 'met', 'mi', 'mic', 'mica', 'mice', 'mite', 'mitt', 'mo', 'moat', 'moi', 'mote', 'motet', 'octet', 'oi', 'omit', 'ta', 'tacit', 'taco', 'tact', 'tame', 'tat', 'tea', 'team', 'teat', 'ti', 'tic', 'tie', 'time', 'tit', 'to', 'toe', 'tom', 'tomcat', 'tome', 'tot', 'tote', 'totem', 'totemic']

# %% [markdown]
# ## Run anagram assist in automatic mode

# %%
words.user_interface('elizabeth stryjewski')
# Out:
# **************************************************
# Welcome to the anagram creator!
# **************************************************
# Looking for anagrams in: elizabeth stryjewski
#
# Remaining letters we have to work with: *elizabethstryjewski*
# You selected: sweatier
#
# Remaining letters we have to work with: *lzbhtyjeski*
# You selected: stye
#
# Remaining letters we have to work with: *lzbhjki*
# You selected: ilk
#
# Remaining letters we have to work with: *zbhj*
# The remaining letters are exhausted or they do not contain possible words
#
# Your name is: elizabeth stryjewski
# Phrase contained within your name: ['sweatier', 'stye', 'ilk']
#
# Note:  the following letters that remained that we could not form words from:
# 	zbhj

# %% [markdown]
# ## Run anagram assist in user interactive mode

# %%
words.user_interface()
# Out:
# **************************************************
# Welcome to the anagram creator!
# **************************************************
# Please enter your first and last name: pimptastic tony
# Looking for anagrams in: pimptastic tony
#
# Remaining letters we have to work with: *pimptastictony*
# Possible words include
# 00) act
# 01) action
# 02) actions
# 03) acts
# 04) aim
# 05) aims
# 06) am
# 07) amity
# 08) amp
# 09) amps
# 10) an
# 11) animist
# 12) animosity
# 13) ant
# 14) anti
# 15) antics
# 16) antis
# 17) ants
# 18) antsy
# 19) any
# 20) appoint
# 21) appoints
# 22) apt
# 23) as
# 24) ascot
# 25) asp
# 26) aspic
# 27) at
# 28) atom
# 29) atomic
# 30) atoms
# 31) atop
# 32) attic
# 33) attics
# 34) ay
# 35) cam
# 36) camp
# 37) camps
# 38) campy
# 39) cams
# 40) can
# 41) canopy
# 42) cans
# 43) cant
# 44) canto
# 45) cantos
# 46) cants
# 47) cap
# 48) capon
# 49) capons
# 50) caps
# 51) caption
# 52) captions
# 53) casino
# 54) cast
# 55) cat
# 56) catnip
# 57) cats
# 58) catty
# 59) ciao
# 60) citation
# 61) citations
# 62) city
# 63) coast
# 64) coat
# 65) coats
# 66) coin
# 67) coins
# 68) coma
# 69) comas
# 70) company
# 71) con
# 72) cons
# 73) cony
# 74) cop
# 75) cops
# 76) copy
# 77) copyist
# 78) cos
# 79) cost
# 80) cosy
# 81) cot
# 82) cots
# 83) coy
# 84) cyan
# 85) cyst
# 86) icon
# 87) icons
# 88) icy
# 89) imp
# 90) impact
# 91) impacts
# 92) imps
# 93) in
# 94) inmost
# 95) intact
# 96) intimacy
# 97) into
# 98) ion
# 99) ions
# 100) iota
# 101) is
# 102) ism
# 103) it
# 104) its
# 105) ma
# 106) mac
# 107) macs
# 108) main
# 109) mains
# 110) man
# 111) manic
# 112) manioc
# 113) mans
# 114) mantis
# 115) many
# 116) map
# 117) maps
# 118) mas
# 119) mascot
# 120) mason
# 121) mast
# 122) mastic
# 123) mat
# 124) matins
# 125) mats
# 126) matt
# 127) mattins
# 128) may
# 129) mayo
# 130) mi
# 131) mic
# 132) mica
# 133) mics
# 134) mini
# 135) minis
# 136) mint
# 137) mints
# 138) minty
# 139) mist
# 140) misty
# 141) mitt
# 142) mitts
# 143) mo
# 144) moan
# 145) moans
# 146) moat
# 147) moats
# 148) moi
# 149) moist
# 150) monastic
# 151) mop
# 152) mops
# 153) mosaic
# 154) most
# 155) my
# 156) myopia
# 157) myopic
# 158) mystic
# 159) nap
# 160) nappy
# 161) naps
# 162) nasty
# 163) natty
# 164) nay
# 165) nip
# 166) nippy
# 167) nips
# 168) nit
# 169) nits
# 170) no
# 171) noisy
# 172) nosy
# 173) not
# 174) oats
# 175) oi
# 176) omit
# 177) omits
# 178) on
# 179) op
# 180) opacity
# 181) ops
# 182) opt
# 183) optic
# 184) optician
# 185) opticians
# 186) optics
# 187) optimist
# 188) opts
# 189) pa
# 190) pact
# 191) pacts
# 192) pacy
# 193) pain
# 194) pains
# 195) paint
# 196) paints
# 197) pan
# 198) panic
# 199) panics
# 200) pans
# 201) pansy
# 202) pant
# 203) panto
# 204) pantos
# 205) pants
# 206) pap
# 207) papist
# 208) pas
# 209) past
# 210) pasty
# 211) pat
# 212) patio
# 213) patios
# 214) patois
# 215) pats
# 216) patsy
# 217) patty
# 218) pay
# 219) pays
# 220) pi
# 221) pianist
# 222) piano
# 223) pianos
# 224) pic
# 225) pics
# 226) pimp
# 227) pimps
# 228) pin
# 229) pins
# 230) pint
# 231) pints
# 232) piny
# 233) pip
# 234) pipit
# 235) pipits
# 236) pips
# 237) piston
# 238) pit
# 239) pita
# 240) pitas
# 241) piton
# 242) pitons
# 243) pits
# 244) pitta
# 245) pittas
# 246) pity
# 247) point
# 248) points
# 249) pointy
# 250) pom
# 251) pomp
# 252) poms
# 253) poncy
# 254) pony
# 255) pop
# 256) pops
# 257) posit
# 258) post
# 259) postman
# 260) posy
# 261) pot
# 262) pots
# 263) potty
# 264) sac
# 265) saint
# 266) sanctity
# 267) sanity
# 268) sap
# 269) sappy
# 270) sat
# 271) satin
# 272) satiny
# 273) say
# 274) scam
# 275) scamp
# 276) scampi
# 277) scan
# 278) scant
# 279) scanty
# 280) scat
# 281) scatty
# 282) scion
# 283) sic
# 284) simian
# 285) sin
# 286) sip
# 287) sit
# 288) sitcom
# 289) snap
# 290) snappy
# 291) snip
# 292) snippy
# 293) snot
# 294) snotty
# 295) so
# 296) soap
# 297) soapy
# 298) son
# 299) sonic
# 300) sop
# 301) soppy
# 302) soy
# 303) soya
# 304) spa
# 305) spam
# 306) span
# 307) spat
# 308) spay
# 309) spic
# 310) spicy
# 311) spin
# 312) spiny
# 313) spit
# 314) spot
# 315) spotty
# 316) spy
# 317) stain
# 318) stamp
# 319) static
# 320) station
# 321) stay
# 322) stint
# 323) stoat
# 324) stoic
# 325) stomp
# 326) stony
# 327) stop
# 328) sty
# 329) synaptic
# 330) sync
# 331) ta
# 332) tacit
# 333) taco
# 334) tacos
# 335) tact
# 336) taint
# 337) taints
# 338) tamp
# 339) tampon
# 340) tampons
# 341) tamps
# 342) tan
# 343) tans
# 344) tap
# 345) taps
# 346) tasty
# 347) tat
# 348) tatty
# 349) ti
# 350) tic
# 351) tics
# 352) timpani
# 353) timpanist
# 354) tin
# 355) tinpot
# 356) tins
# 357) tint
# 358) tints
# 359) tiny
# 360) tip
# 361) tips
# 362) tipsy
# 363) tit
# 364) titan
# 365) titanic
# 366) titans
# 367) titian
# 368) tits
# 369) titty
# 370) to
# 371) toast
# 372) toasty
# 373) tom
# 374) tomcat
# 375) tomcats
# 376) toms
# 377) ton
# 378) tonic
# 379) tonics
# 380) tons
# 381) tony
# 382) top
# 383) topi
# 384) topic
# 385) topics
# 386) topis
# 387) tops
# 388) topspin
# 389) tot
# 390) tots
# 391) toy
# 392) toys
# 393) typist
# 394) typo
# 395) typos
# 396) yam
# 397) yams
# 398) yap
# 399) yaps
# 400) yin
# 401) yip
# 402) yips
# 403) yo
# 404) yon
#
# Please enter your choice: 199
# You selected: panics
#
# Remaining letters we have to work with: *mpttitoy*
# Possible words include
# 00) imp
# 01) it
# 02) mi
# 03) mitt
# 04) mo
# 05) moi
# 06) mop
# 07) my
# 08) oi
# 09) omit
# 10) op
# 11) opt
# 12) pi
# 13) pit
# 14) pity
# 15) pom
# 16) pot
# 17) potty
# 18) ti
# 19) tip
# 20) tit
# 21) titty
# 22) to
# 23) tom
# 24) top
# 25) topi
# 26) tot
# 27) toy
# 28) typo
# 29) yip
# 30) yo
#
# Please enter your choice: 30
# You selected: yo
#
# Remaining letters we have to work with: *mpttit*
# Possible words include
# 00) imp
# 01) it
# 02) mi
# 03) mitt
# 04) pi
# 05) pit
# 06) ti
# 07) tip
# 08) tit
#
# Please enter your choice: 08
# You selected: tit
#
# Remaining letters we have to work with: *mpt*
# The remaining letters are exhausted or they do not contain possible words
#
# Your name is: pimptastic tony
# Phrase contained within your name: ['panics', 'yo', 'tit']
#
# Note:  the following letters that remained that we could not form words from:
# 	mpt
